# %%
enable_wandb=True
if enable_wandb:
    import wandb

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: deepakpokkalla. Use `wandb login --relogin` to force relogin
# True

# %%
import os 
import pdb
import torch 
import pandas 

os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Out:
# 2.4.0+cu124

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())
    plt.figure(figsize=(10,10))
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.scatter(z[:,0],z[:,1],s=70,c=color,cmap="Set2")

def embedding_to_wandb(h, color, key="embedding"):
    num_components = h.shape[-1]
    df = pandas.DataFrame(data=h.detach().cpu().numpy(),
                        columns=[f"c_{i}" for i in range(num_components)])
    df["target"] = color.detach().cpu().numpy().astype("str")
    cols = df.columns.tolist()
    df = df[cols[-1:] + cols[:-1]]
    wandb.log({key: df})

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='../datasets/Planetoid', name="Cora", transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}')
print(f'# features: {dataset.num_features}')
print(f'# classes: {dataset.num_classes}')
print(f'# graphs: {len(dataset)}')
# Out:
# Dataset: Cora()
# # features: 1433
# # classes: 7
# # graphs: 1

# %%
data = dataset[0]

print()
print(data)
print()

# gather info
print(f'# nodes: {data.num_nodes}')
print(f'# edges: {data.num_edges}')
print(f'avg node degree: {data.num_edges/data.num_nodes:.2f}')
print(f'# training nodes: {data.train_mask.sum()}')
print(f'training node label rate: {int(data.train_mask.sum())/data.num_nodes:.2f}')
print(f'has isolated nodes: {data.has_isolated_nodes()}')
print(f'has self-loops: {data.has_self_loops()}')
print(f'is undirected: {data.is_undirected()}')
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
#
# # nodes: 2708
# # edges: 10556
# avg node degree: 3.90
# # training nodes: 140
# training node label rate: 0.05
# has isolated nodes: False
# has self-loops: False
# is undirected: True

# %% [markdown]
# #### Train an MLP

# %%
import torch 
from torch.nn import Linear
import torch.nn.functional as F

class MLP(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(12345)
        self.lin1 = Linear(dataset.num_features,hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)
    
    def forward(self,x):
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x

# %%
if enable_wandb:
    wandb.init(project='pyg-colab-node-classification')
    summary = dict()
    summary["data"] = dict()
    summary["data"]["num_features"] = dataset.num_features
    summary["data"]["num_classes"] = dataset.num_classes
    summary["data"]["num_nodes"] = data.num_nodes
    summary["data"]["num_edges"] = data.num_edges 
    summary["data"]["has_isolated_nodes"] = data.has_isolated_nodes()
    summary["data"]["has_self_nodes"] = data.has_self_loops()
    summary["data"]["is_undirected"] = data.is_undirected()
    summary["data"]["num_training_nodes"] = data.train_mask.sum()
    wandb.summary = summary
# Out:
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_160213-bpahsnci</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification/runs/bpahsnci' target="_blank">glad-salad-1</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-colab-node-classification</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification/runs/bpahsnci' target="_blank">https://wandb.ai/deepakpokkalla/pyg-colab-node-classification/runs/bpahsnci</a>

# %%
model = MLP(16)
print(f'model: {model}')

with torch.no_grad():
    out = model(data.x)

# if enable_wandb:
#     embedding_to_wandb(out, color=data.y, key="mlp/embedding/init")
# else:
#     visualize(out, data.y)

embedding_to_wandb(out, color=data.y, key="mlp/embedding/init")
visualize(out, data.y)
# Out:
# model: MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
# )

# %%
# out.shape, data.y.min(), data.y.max()

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x)
    loss = criterion(out[data.train_mask],data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss

def test():
    model.eval()
    out = model(data.x)
    pred = out.argmax(dim=1)
    correct = pred[data.test_mask] == data.y[data.test_mask]
    acc = int(correct.sum())/int(data.test_mask.sum())
    return acc

for epoch in range(1,201):
    loss = train()
    if enable_wandb:
        wandb.log({"mlp/loss": loss})
    print(f'Epoch: {epoch:03d}, Loss:{loss:.4f}')
# Out:
# Epoch: 001, Loss:1.9616
# Epoch: 002, Loss:1.9564
# Epoch: 003, Loss:1.9495
# Epoch: 004, Loss:1.9419
# Epoch: 005, Loss:1.9369
# Epoch: 006, Loss:1.9244
# Epoch: 007, Loss:1.9196
# Epoch: 008, Loss:1.9131
# Epoch: 009, Loss:1.9019
# Epoch: 010, Loss:1.8895
# Epoch: 011, Loss:1.8737
# Epoch: 012, Loss:1.8616
# Epoch: 013, Loss:1.8539
# Epoch: 014, Loss:1.8458
# Epoch: 015, Loss:1.8197
# Epoch: 016, Loss:1.8194
# Epoch: 017, Loss:1.8027
# Epoch: 018, Loss:1.7732
# Epoch: 019, Loss:1.7733
# Epoch: 020, Loss:1.7491
# Epoch: 021, Loss:1.7472
# Epoch: 022, Loss:1.7194
# Epoch: 023, Loss:1.6962
# Epoch: 024, Loss:1.6584
# Epoch: 025, Loss:1.6668
# Epoch: 026, Loss:1.6226
# Epoch: 027, Loss:1.6333
# Epoch: 028, Loss:1.6029
# Epoch: 029, Loss:1.5534
# Epoch: 030, Loss:1.5783
# Epoch: 031, Loss:1.5381
# Epoch: 032, Loss:1.5213
# Epoch: 033, Loss:1.4926
# Epoch: 034, Loss:1.4652
# Epoch: 035, Loss:1.4754
# Epoch: 036, Loss:1.4559
# Epoch: 037, Loss:1.3932
# Epoch: 038, Loss:1.3604
# Epoch: 039, Loss:1.3321
# Epoch: 040, Loss:1.3120
# Epoch: 041, Loss:1.3279
# Epoch: 042, Loss:1.2808
# Epoch: 043, Loss:1.2763
# Epoch: 044, Loss:1.2019
# Epoch: 045, Loss:1.2157
# Epoch: 046, Loss:1.2172
# Epoch: 047, Loss:1.1339
# Epoch: 048, Loss:1.1496
# Epoch: 049, Loss:1.1386
# Epoch: 050, Loss:1.0673
# Epoch: 051, Loss:1.1616
# Epoch: 052, Loss:1.0247
# Epoch: 053, Loss:1.0694
# Epoch: 054, Loss:1.0018
# Epoch: 055, Loss:0.9785
# Epoch: 056, Loss:1.0106
# Epoch: 057, Loss:1.0105
# Epoch: 058, Loss:0.9718
# Epoch: 059, Loss:0.9639
# Epoch: 060, Loss:0.9019
# Epoch: 061, Loss:0.8995
# Epoch: 062, Loss:0.8695
# Epoch: 063, Loss:0.8682
# Epoch: 064, Loss:0.8250
# Epoch: 065, Loss:0.8014
# Epoch: 066, Loss:0.8247
# Epoch: 067, Loss:0.7925
# Epoch: 068, Loss:0.8540
# Epoch: 069, Loss:0.7777
# Epoch: 070, Loss:0.8286
# Epoch: 071, Loss:0.8134
# Epoch: 072, Loss:0.8253
# Epoch: 073, Loss:0.7168
# Epoch: 074, Loss:0.7793
# Epoch: 075, Loss:0.7405
# Epoch: 076, Loss:0.7415
# Epoch: 077, Loss:0.7100
# Epoch: 078, Loss:0.6721
# Epoch: 079, Loss:0.7407
# Epoch: 080, Loss:0.7605
# Epoch: 081, Loss:0.7553
# Epoch: 082, Loss:0.7232
# Epoch: 083, Loss:0.6985
# Epoch: 084, Loss:0.6699
# Epoch: 085, Loss:0.5636
# Epoch: 086, Loss:0.7485
# Epoch: 087, Loss:0.7064
# Epoch: 088, Loss:0.6008
# Epoch: 089, Loss:0.6639
# Epoch: 090, Loss:0.7401
# Epoch: 091, Loss:0.5986
# Epoch: 092, Loss:0.6737
# Epoch: 093, Loss:0.6066
# Epoch: 094, Loss:0.5517
# Epoch: 095, Loss:0.6073
# Epoch: 096, Loss:0.6436
# Epoch: 097, Loss:0.6297
# Epoch: 098, Loss:0.6078
# Epoch: 099, Loss:0.6225
# Epoch: 100, Loss:0.6201
# Epoch: 101, Loss:0.5874
# Epoch: 102, Loss:0.6136
# Epoch: 103, Loss:0.5951
# Epoch: 104, Loss:0.6438
# Epoch: 105, Loss:0.5912
# Epoch: 106, Loss:0.5279
# Epoch: 107, Loss:0.5831
# Epoch: 108, Loss:0.5407
# Epoch: 109, Loss:0.5737
# Epoch: 110, Loss:0.5817
# Epoch: 111, Loss:0.5497
# Epoch: 112, Loss:0.5424
# Epoch: 113, Loss:0.5389
# Epoch: 114, Loss:0.5013
# Epoch: 115, Loss:0.5692
# Epoch: 116, Loss:0.5295
# Epoch: 117, Loss:0.5958
# Epoch: 118, Loss:0.4636
# Epoch: 119, Loss:0.5565
# Epoch: 120, Loss:0.5443
# Epoch: 121, Loss:0.5215
# Epoch: 122, Loss:0.6427
# Epoch: 123, Loss:0.5298
# Epoch: 124, Loss:0.5397
# Epoch: 125, Loss:0.5192
# Epoch: 126, Loss:0.5170
# Epoch: 127, Loss:0.4237
# Epoch: 128, Loss:0.5217
# Epoch: 129, Loss:0.5696
# Epoch: 130, Loss:0.4737
# Epoch: 131, Loss:0.5383
# Epoch: 132, Loss:0.5021
# Epoch: 133, Loss:0.4610
# Epoch: 134, Loss:0.4859
# Epoch: 135, Loss:0.5373
# Epoch: 136, Loss:0.4819
# Epoch: 137, Loss:0.5313
# Epoch: 138, Loss:0.5054
# Epoch: 139, Loss:0.4998
# Epoch: 140, Loss:0.4829
# Epoch: 141, Loss:0.5089
# Epoch: 142, Loss:0.4510
# Epoch: 143, Loss:0.4862
# Epoch: 144, Loss:0.5393
# Epoch: 145, Loss:0.4560
# Epoch: 146, Loss:0.5247
# Epoch: 147, Loss:0.4129
# Epoch: 148, Loss:0.5054
# Epoch: 149, Loss:0.4552
# Epoch: 150, Loss:0.5066
# Epoch: 151, Loss:0.4362
# Epoch: 152, Loss:0.5611
# Epoch: 153, Loss:0.5143
# Epoch: 154, Loss:0.4968
# Epoch: 155, Loss:0.4920
# Epoch: 156, Loss:0.5228
# Epoch: 157, Loss:0.5010
# Epoch: 158, Loss:0.4714
# Epoch: 159, Loss:0.4345
# Epoch: 160, Loss:0.4661
# Epoch: 161, Loss:0.5205
# Epoch: 162, Loss:0.4703
# Epoch: 163, Loss:0.5345
# Epoch: 164, Loss:0.4197
# Epoch: 165, Loss:0.4318
# Epoch: 166, Loss:0.4903
# Epoch: 167, Loss:0.5184
# Epoch: 168, Loss:0.4699
# Epoch: 169, Loss:0.4549
# Epoch: 170, Loss:0.5010
# Epoch: 171, Loss:0.4726
# Epoch: 172, Loss:0.4575
# Epoch: 173, Loss:0.4919
# Epoch: 174, Loss:0.4836
# Epoch: 175, Loss:0.4397
# Epoch: 176, Loss:0.4571
# Epoch: 177, Loss:0.4768
# Epoch: 178, Loss:0.4378
# Epoch: 179, Loss:0.4794
# Epoch: 180, Loss:0.4498
# Epoch: 181, Loss:0.4129
# Epoch: 182, Loss:0.4909
# Epoch: 183, Loss:0.4914
# Epoch: 184, Loss:0.5126
# Epoch: 185, Loss:0.5183
# Epoch: 186, Loss:0.5523
# Epoch: 187, Loss:0.4115
# Epoch: 188, Loss:0.5726
# Epoch: 189, Loss:0.4529
# Epoch: 190, Loss:0.4602
# Epoch: 191, Loss:0.3932
# Epoch: 192, Loss:0.4640
# Epoch: 193, Loss:0.4624
# Epoch: 194, Loss:0.4684
# Epoch: 195, Loss:0.4069
# Epoch: 196, Loss:0.4914
# Epoch: 197, Loss:0.5102
# Epoch: 198, Loss:0.4421
# Epoch: 199, Loss:0.4751
# Epoch: 200, Loss:0.4655

# %%
test_acc = test()
out = model(data.x)
print(enable_wandb)
if enable_wandb:
    embedding_to_wandb(out, color=data.y, key="mlp/embedding/trained")
    wandb.summary["mlp/accuracy"]=test_acc
    wandb.log({"mlp/accuracy": test_acc})
else:
    visualize(out,data.y)

print(f'Test accuracy: {test_acc:.4f}')
# Out:
# True
# Test accuracy: 0.6040

# %%
visualize(out,data.y)

# %% [markdown]
# #### Train a GNN

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)
    
    def forward(self,x,edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x,edge_index)
        return x

model = GCN(16)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
# )

# %%
model = GCN(hidden_channels=16)
model.eval()

out = model(data.x, data.edge_index)

if enable_wandb:
    embedding_to_wandb(out, color=data.y, key="gcn/embedding/init")
else:
    visualize(out, data.y)

# %%
visualize(out, data.y)

# %%
model = GCN(16)
print(model)

if enable_wandb:
    wandb.watch(model)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask],data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss

def test():
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
    test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
    return test_acc

for epoch in range(1,101):
    loss=train()
    if enable_wandb:
        wandb.log({"gcn/loss": loss})
    print(f'Epoch: {epoch:03d}, Loss:{loss:.4f}')
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
# )
# Epoch: 001, Loss:1.9452
# Epoch: 002, Loss:1.9420
# Epoch: 003, Loss:1.9360
# Epoch: 004, Loss:1.9273
# Epoch: 005, Loss:1.9155
# Epoch: 006, Loss:1.9104
# Epoch: 007, Loss:1.9083
# Epoch: 008, Loss:1.9045
# Epoch: 009, Loss:1.8889
# Epoch: 010, Loss:1.8853
# Epoch: 011, Loss:1.8911
# Epoch: 012, Loss:1.8729
# Epoch: 013, Loss:1.8683
# Epoch: 014, Loss:1.8543
# Epoch: 015, Loss:1.8562
# Epoch: 016, Loss:1.8541
# Epoch: 017, Loss:1.8370
# Epoch: 018, Loss:1.8311
# Epoch: 019, Loss:1.8142
# Epoch: 020, Loss:1.8128
# Epoch: 021, Loss:1.7928
# Epoch: 022, Loss:1.7799
# Epoch: 023, Loss:1.7850
# Epoch: 024, Loss:1.7774
# Epoch: 025, Loss:1.7683
# Epoch: 026, Loss:1.7716
# Epoch: 027, Loss:1.7451
# Epoch: 028, Loss:1.7451
# Epoch: 029, Loss:1.7238
# Epoch: 030, Loss:1.7237
# Epoch: 031, Loss:1.6777
# Epoch: 032, Loss:1.6869
# Epoch: 033, Loss:1.6664
# Epoch: 034, Loss:1.6714
# Epoch: 035, Loss:1.6688
# Epoch: 036, Loss:1.6455
# Epoch: 037, Loss:1.6142
# Epoch: 038, Loss:1.6111
# Epoch: 039, Loss:1.5671
# Epoch: 040, Loss:1.6243
# Epoch: 041, Loss:1.5818
# Epoch: 042, Loss:1.5300
# Epoch: 043, Loss:1.5320
# Epoch: 044, Loss:1.5008
# Epoch: 045, Loss:1.5265
# Epoch: 046, Loss:1.4933
# Epoch: 047, Loss:1.4674
# Epoch: 048, Loss:1.4824
# Epoch: 049, Loss:1.4729
# Epoch: 050, Loss:1.4316
# Epoch: 051, Loss:1.4160
# Epoch: 052, Loss:1.4192
# Epoch: 053, Loss:1.4142
# Epoch: 054, Loss:1.3887
# Epoch: 055, Loss:1.3431
# Epoch: 056, Loss:1.3338
# Epoch: 057, Loss:1.3452
# Epoch: 058, Loss:1.3343
# Epoch: 059, Loss:1.3075
# Epoch: 060, Loss:1.3070
# Epoch: 061, Loss:1.2645
# Epoch: 062, Loss:1.3005
# Epoch: 063, Loss:1.2657
# Epoch: 064, Loss:1.2522
# Epoch: 065, Loss:1.1723
# Epoch: 066, Loss:1.2075
# Epoch: 067, Loss:1.1776
# Epoch: 068, Loss:1.2117
# Epoch: 069, Loss:1.1235
# Epoch: 070, Loss:1.1191
# Epoch: 071, Loss:1.1237
# Epoch: 072, Loss:1.0822
# Epoch: 073, Loss:1.1260
# Epoch: 074, Loss:1.0602
# Epoch: 075, Loss:1.1296
# Epoch: 076, Loss:1.0952
# Epoch: 077, Loss:1.1353
# Epoch: 078, Loss:1.1294
# Epoch: 079, Loss:1.0499
# Epoch: 080, Loss:0.9829
# Epoch: 081, Loss:1.0504
# Epoch: 082, Loss:1.0564
# Epoch: 083, Loss:0.9473
# Epoch: 084, Loss:0.9231
# Epoch: 085, Loss:0.9904
# Epoch: 086, Loss:0.9813
# Epoch: 087, Loss:0.9823
# Epoch: 088, Loss:0.9390
# Epoch: 089, Loss:0.9792
# Epoch: 090, Loss:0.9811
# Epoch: 091, Loss:0.9087
# Epoch: 092, Loss:0.8972
# Epoch: 093, Loss:0.9177
# Epoch: 094, Loss:0.9272
# Epoch: 095, Loss:0.8727
# Epoch: 096, Loss:0.9327
# Epoch: 097, Loss:0.8714
# Epoch: 098, Loss:0.8262
# Epoch: 099, Loss:0.8822
# Epoch: 100, Loss:0.8706

# %%
test_acc = test()
print(f'test_acc: {test_acc}')
# Out:
# test_acc: 0.796

# %%
model.eval()

out = model(data.x, data.edge_index)

if enable_wandb:
    wandb.summary["gcn/accuracy"] = test_acc
    wandb.log({"gcn/accuracy": test_acc})
    embedding_to_wandb(out, color=data.y, key="gcn/embedding/trained")
    wandb.finish()
else:
    visualize(out, data.y)
# Out:
# VBox(children=(Label(value='3.298 MB of 3.298 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▁▂▂▂▁</td></tr><tr><td>mlp/accuracy</td><td>▁</td></tr><tr><td>mlp/loss</td><td>█▇▇▇▇▆▅▅▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.796</td></tr><tr><td>gcn/loss</td><td>0.87055</td></tr><tr><td>mlp/accuracy</td><td>0.604</td></tr><tr><td>mlp/loss</td><td>0.46549</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glad-salad-1</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification/runs/bpahsnci' target="_blank">https://wandb.ai/deepakpokkalla/pyg-colab-node-classification/runs/bpahsnci</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-colab-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-colab-node-classification</a><br/>Synced 4 W&B file(s), 0 media file(s), 11 artifact file(s) and 4 other file(s)
# Find logs at: <code>.\wandb\run-20241125_160213-bpahsnci\logs</code>

# %%
visualize(out, data.y)

# %% [markdown]
# ### Using W&B Sweeps

# %%
wandb.login
# Out:
# <function wandb.sdk.wandb_login.login(anonymous: Optional[Literal['must', 'allow', 'never']] = None, key: Optional[str] = None, relogin: Optional[bool] = None, host: Optional[str] = None, force: Optional[bool] = None, timeout: Optional[int] = None, verify: bool = False) -> bool>

# %%
import tqdm

def agent_fn():
    wandb.init()
    model = GCN(hidden_channels=wandb.config.hidden_channels)
    wandb.watch(model)

    with torch.no_grad():
        out = model(data.x, data.edge_index)
        embedding_to_wandb(out, color=data.y, key="gcn/embedding/init")
    
    optimizer = torch.optim.Adam(model.parameters(), lr=wandb.config.lr, weight_decay=wandb.config.weight_decay)
    criterion = torch.nn.CrossEntropyLoss()

    def train():
          model.train()
          optimizer.zero_grad()  # Clear gradients.
          out = model(data.x, data.edge_index)  # Perform a single forward pass.
          loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
          loss.backward()  # Derive gradients.
          optimizer.step()  # Update parameters based on gradients.
          return loss

    def test():
          model.eval()
          out = model(data.x, data.edge_index)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
          test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
          return test_acc

    for epoch in tqdm.tqdm(range(1, 101)):
        loss = train()
        wandb.log({"gcn/loss": loss})

    model.eval()

    out = model(data.x, data.edge_index)
    test_acc = test()
    wandb.summary["gcn/accuracy"] = test_acc
    wandb.log({"gcn/accuracy": test_acc})
    embedding_to_wandb(out, color=data.y, key="gcn/embedding/trained")
    wandb.finish()

# %%
sweep_config = {
    "name": "gcn-sweep",
    "method": "bayes",
    "metric": {
        "name": "gcn/accuracy",
        "goal": "maximize",
    },
    "parameters": {
        "hidden_channels": {
            "values": [8, 16, 32]
        },
        "weight_decay": {
            "distribution": "normal",
            "mu": 5e-4,
            "sigma": 1e-5,
        },
        "lr": {
            "min": 1e-4,
            "max": 1e-3
        }
    }
}

# Register the Sweep with W&B
sweep_id = wandb.sweep(sweep_config, project="pyg-node-classification")
# Out:
# Create sweep with ID: d99tj2ln
# Sweep URL: https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln

# %%
wandb.agent(sweep_id, project="pyg-node-classification", function=agent_fn, count=50)
# Out:
# wandb: Agent Starting Run: zyr3bwf7 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0005310691337424886
# wandb: 	weight_decay: 0.000494558459845563
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161030-zyr3bwf7</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zyr3bwf7' target="_blank">dazzling-sweep-1</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zyr3bwf7' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zyr3bwf7</a>
# 100%|██████████| 100/100 [00:00<00:00, 113.54it/s]
# VBox(children=(Label(value='0.865 MB of 1.738 MB uploaded\r'), FloatProgress(value=0.49777801433110797, max=1.…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█▇██▇▇▇▇▇▆▆▆▆▅▅▅▅▅▅▅▅▅▆▄▄▄▄▄▄▄▄▄▃▄▂▃▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.656</td></tr><tr><td>gcn/loss</td><td>1.90796</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dazzling-sweep-1</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zyr3bwf7' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zyr3bwf7</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 4 W&B file(s), 0 media file(s), 7 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161030-zyr3bwf7\logs</code>
# wandb: Agent Starting Run: qe43lod3 with config:
# wandb: 	hidden_channels: 8
# wandb: 	lr: 0.0004708961638731445
# wandb: 	weight_decay: 0.0004805592738921111
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161040-qe43lod3</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/qe43lod3' target="_blank">sweet-sweep-2</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/qe43lod3' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/qe43lod3</a>
# 100%|██████████| 100/100 [00:00<00:00, 165.74it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>████▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▂▃▂▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.567</td></tr><tr><td>gcn/loss</td><td>1.91059</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweet-sweep-2</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/qe43lod3' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/qe43lod3</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161040-qe43lod3\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ltpsffes with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0008657979315308059
# wandb: 	weight_decay: 0.0005006181101825065
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161055-ltpsffes</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ltpsffes' target="_blank">stoic-sweep-3</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ltpsffes' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ltpsffes</a>
# 100%|██████████| 100/100 [00:01<00:00, 83.64it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█▇▇█▇▇▇▇▇▇▆▇▆▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▄▃▄▄▂▃▂▃▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.665</td></tr><tr><td>gcn/loss</td><td>1.87244</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stoic-sweep-3</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ltpsffes' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ltpsffes</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161055-ltpsffes\logs</code>
# wandb: Agent Starting Run: s49u5l1t with config:
# wandb: 	hidden_channels: 8
# wandb: 	lr: 0.0005590168878468707
# wandb: 	weight_decay: 0.0004891034301521933
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161106-s49u5l1t</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/s49u5l1t' target="_blank">misunderstood-sweep-4</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/s49u5l1t' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/s49u5l1t</a>
# 100%|██████████| 100/100 [00:00<00:00, 165.74it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█████▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▅▅▄▄▄▄▃▃▂▃▃▃▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.569</td></tr><tr><td>gcn/loss</td><td>1.90311</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misunderstood-sweep-4</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/s49u5l1t' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/s49u5l1t</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161106-s49u5l1t\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jkw969ob with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.0006475435820962072
# wandb: 	weight_decay: 0.0005000896888447186
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161121-jkw969ob</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jkw969ob' target="_blank">swift-sweep-5</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jkw969ob' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jkw969ob</a>
# 100%|██████████| 100/100 [00:01<00:00, 76.39it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██████▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▄▄▃▃▄▃▃▃▂▂▂▂▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.654</td></tr><tr><td>gcn/loss</td><td>1.83827</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swift-sweep-5</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jkw969ob' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jkw969ob</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161121-jkw969ob\logs</code>
# wandb: Agent Starting Run: kx1zn66t with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.0006503241930690194
# wandb: 	weight_decay: 0.0005002985544304232
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161132-kx1zn66t</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/kx1zn66t' target="_blank">rose-sweep-6</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/kx1zn66t' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/kx1zn66t</a>
# 100%|██████████| 100/100 [00:01<00:00, 75.28it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>████▇█▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.647</td></tr><tr><td>gcn/loss</td><td>1.84151</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rose-sweep-6</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/kx1zn66t' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/kx1zn66t</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161132-kx1zn66t\logs</code>
# wandb: Agent Starting Run: 5vhzmnh8 with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.0005768515070710549
# wandb: 	weight_decay: 0.0004984181333391288
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161142-5vhzmnh8</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/5vhzmnh8' target="_blank">dandy-sweep-7</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/5vhzmnh8' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/5vhzmnh8</a>
# 100%|██████████| 100/100 [00:01<00:00, 80.29it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█████▇▇▇▇▇▆▆▆▆▆▅▆▅▅▅▅▅▅▅▅▄▄▄▄▄▃▄▃▃▃▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.653</td></tr><tr><td>gcn/loss</td><td>1.84711</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dandy-sweep-7</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/5vhzmnh8' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/5vhzmnh8</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161142-5vhzmnh8\logs</code>
# wandb: Agent Starting Run: 4l5vcgg8 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0007649017048587241
# wandb: 	weight_decay: 0.0004997047292566324
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161153-4l5vcgg8</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/4l5vcgg8' target="_blank">sweepy-sweep-8</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/4l5vcgg8' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/4l5vcgg8</a>
# 100%|██████████| 100/100 [00:01<00:00, 83.82it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▇██▇▇▇▇▇▆▆▆▆▆▅▅▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▂▂▃▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.66</td></tr><tr><td>gcn/loss</td><td>1.88272</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweepy-sweep-8</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/4l5vcgg8' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/4l5vcgg8</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161153-4l5vcgg8\logs</code>
# wandb: Agent Starting Run: ig3rrxgc with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.0006939721830893702
# wandb: 	weight_decay: 0.0004977665878240587
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161203-ig3rrxgc</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ig3rrxgc' target="_blank">proud-sweep-9</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ig3rrxgc' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ig3rrxgc</a>
# 100%|██████████| 100/100 [00:01<00:00, 70.76it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██████▇▇▇▇▇▇▆▆▆▆▅▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.635</td></tr><tr><td>gcn/loss</td><td>1.8305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">proud-sweep-9</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ig3rrxgc' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ig3rrxgc</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161203-ig3rrxgc\logs</code>
# wandb: Agent Starting Run: x022n9l6 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.00017690073192380226
# wandb: 	weight_decay: 0.0005103704688416895
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161214-x022n9l6</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/x022n9l6' target="_blank">silver-sweep-10</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/x022n9l6' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/x022n9l6</a>
# 100%|██████████| 100/100 [00:00<00:00, 104.68it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▅▇▆▇█▆▇▇▆▇▅▇▅▅▅▆▆▄▅▄▄▅▄▄▄▅▅▃▂▃▄▁▁▂▃▄▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.541</td></tr><tr><td>gcn/loss</td><td>1.9383</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">silver-sweep-10</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/x022n9l6' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/x022n9l6</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161214-x022n9l6\logs</code>
# wandb: Agent Starting Run: wna5utud with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0008375369477347393
# wandb: 	weight_decay: 0.000497708120290363
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161224-wna5utud</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/wna5utud' target="_blank">wild-sweep-11</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/wna5utud' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/wna5utud</a>
# 100%|██████████| 100/100 [00:00<00:00, 105.23it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>████▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▅▅▄▄▄▄▄▄▃▄▄▂▂▂▂▃▂▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.681</td></tr><tr><td>gcn/loss</td><td>1.87185</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wild-sweep-11</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/wna5utud' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/wna5utud</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161224-wna5utud\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: lrp1ra6z with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.000928638858335744
# wandb: 	weight_decay: 0.000497391357414743
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161240-lrp1ra6z</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lrp1ra6z' target="_blank">worldly-sweep-12</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lrp1ra6z' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lrp1ra6z</a>
# 100%|██████████| 100/100 [00:01<00:00, 73.60it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▃▃▃▂▃▃▃▄▂▂▃▂▂▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.656</td></tr><tr><td>gcn/loss</td><td>1.86775</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-sweep-12</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lrp1ra6z' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lrp1ra6z</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161240-lrp1ra6z\logs</code>
# wandb: Agent Starting Run: faju6o6e with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0007996371005912059
# wandb: 	weight_decay: 0.0004954671273132004
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161250-faju6o6e</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/faju6o6e' target="_blank">fanciful-sweep-13</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/faju6o6e' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/faju6o6e</a>
# 100%|██████████| 100/100 [00:01<00:00, 73.24it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>███▇██▇▇▇▇▆▇▆▇▆▆▆▅▆▅▅▅▅▅▅▄▃▄▃▄▄▃▄▄▄▃▂▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.688</td></tr><tr><td>gcn/loss</td><td>1.87732</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fanciful-sweep-13</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/faju6o6e' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/faju6o6e</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161250-faju6o6e\logs</code>
# wandb: Agent Starting Run: 0ncpufd2 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0007533535516004488
# wandb: 	weight_decay: 0.0004963249508523597
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161301-0ncpufd2</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/0ncpufd2' target="_blank">comic-sweep-14</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/0ncpufd2' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/0ncpufd2</a>
# 100%|██████████| 100/100 [00:01<00:00, 99.34it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▇█▇▇█▇▇▇▇▆▆▆▆▅▆▅▅▅▅▄▅▄▄▄▄▄▄▃▄▄▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.672</td></tr><tr><td>gcn/loss</td><td>1.88402</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comic-sweep-14</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/0ncpufd2' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/0ncpufd2</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161301-0ncpufd2\logs</code>
# wandb: Agent Starting Run: ll8ruyg1 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0008105692607774843
# wandb: 	weight_decay: 0.0004958287766846795
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161312-ll8ruyg1</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ll8ruyg1' target="_blank">breezy-sweep-15</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ll8ruyg1' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ll8ruyg1</a>
# 100%|██████████| 100/100 [00:00<00:00, 107.98it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▇▇█▇▇▇▇▇▆▇▇▇▆▆▆▆▆▅▅▄▅▄▄▄▄▄▄▄▃▃▃▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.664</td></tr><tr><td>gcn/loss</td><td>1.87559</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">breezy-sweep-15</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ll8ruyg1' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/ll8ruyg1</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161312-ll8ruyg1\logs</code>
# wandb: Agent Starting Run: poy270rw with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0004509561483676716
# wandb: 	weight_decay: 0.000496646243141578
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161322-poy270rw</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/poy270rw' target="_blank">true-sweep-16</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/poy270rw' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/poy270rw</a>
# 100%|██████████| 100/100 [00:00<00:00, 111.29it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>███▇▇▇▇▆▇▇▆▇▆▆▅▅▅▆▅▅▆▅▄▄▄▄▃▄▂▄▄▂▂▃▃▃▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.693</td></tr><tr><td>gcn/loss</td><td>1.9133</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">true-sweep-16</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/poy270rw' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/poy270rw</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161322-poy270rw\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: xsrlbxx9 with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.00010861607823605712
# wandb: 	weight_decay: 0.0005022177148916903
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161340-xsrlbxx9</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/xsrlbxx9' target="_blank">fresh-sweep-17</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/xsrlbxx9' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/xsrlbxx9</a>
# 100%|██████████| 100/100 [00:02<00:00, 49.34it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>▇▆█▇▇██▆▇▇▇█▆▇▆▆▇▆▅▅▅▅▅▅▄▅▄▄▃▄▃▄▃▃▃▁▃▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.57</td></tr><tr><td>gcn/loss</td><td>1.93332</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fresh-sweep-17</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/xsrlbxx9' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/xsrlbxx9</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161340-xsrlbxx9\logs</code>
# ...
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lzb4b3vp' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lzb4b3vp</a>
# 100%|██████████| 100/100 [00:00<00:00, 168.22it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█████▇▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.577</td></tr><tr><td>gcn/loss</td><td>1.89549</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">amber-sweep-45</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lzb4b3vp' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/lzb4b3vp</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161916-lzb4b3vp\logs</code>
# wandb: Agent Starting Run: jo5qlnie with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0008039660265929903
# wandb: 	weight_decay: 0.000497072514151878
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161926-jo5qlnie</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jo5qlnie' target="_blank">colorful-sweep-46</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jo5qlnie' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jo5qlnie</a>
# 100%|██████████| 100/100 [00:00<00:00, 102.26it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█▇█▇██▇▇▇▇▇▆▆▆▆▅▅▅▅▄▅▄▄▄▄▃▄▄▄▄▃▃▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.678</td></tr><tr><td>gcn/loss</td><td>1.87994</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-46</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jo5qlnie' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/jo5qlnie</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161926-jo5qlnie\logs</code>
# wandb: Agent Starting Run: zafcdgf6 with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0008533220240654344
# wandb: 	weight_decay: 0.0005024722406272713
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161937-zafcdgf6</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zafcdgf6' target="_blank">summer-sweep-47</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zafcdgf6' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zafcdgf6</a>
# 100%|██████████| 100/100 [00:00<00:00, 109.41it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▇▇▇▇▇▆▇▆▆▆▆▆▆▅▅▅▅▅▄▅▅▅▄▄▄▃▃▃▃▃▃▄▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.683</td></tr><tr><td>gcn/loss</td><td>1.86809</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">summer-sweep-47</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zafcdgf6' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/zafcdgf6</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161937-zafcdgf6\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bwzl9coq with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.000916657525098394
# wandb: 	weight_decay: 0.0005154943031538191
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_161953-bwzl9coq</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/bwzl9coq' target="_blank">lunar-sweep-48</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/bwzl9coq' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/bwzl9coq</a>
# 100%|██████████| 100/100 [00:00<00:00, 112.24it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>█████████▇▇▇▆▇▆▆▆▅▅▅▅▅▄▅▄▄▄▄▄▄▄▃▃▃▂▃▃▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.671</td></tr><tr><td>gcn/loss</td><td>1.86668</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lunar-sweep-48</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/bwzl9coq' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/bwzl9coq</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_161953-bwzl9coq\logs</code>
# wandb: Agent Starting Run: 1zoffbcw with config:
# wandb: 	hidden_channels: 16
# wandb: 	lr: 0.0009173416654004676
# wandb: 	weight_decay: 0.0005022565685413983
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_162004-1zoffbcw</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/1zoffbcw' target="_blank">lemon-sweep-49</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/1zoffbcw' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/1zoffbcw</a>
# 100%|██████████| 100/100 [00:01<00:00, 67.97it/s]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>██▇█▇▇▇▇▇▇▆▇▆▆▆▆▆▅▅▅▅▄▅▄▅▄▄▃▄▃▃▂▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.64</td></tr><tr><td>gcn/loss</td><td>1.87013</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lemon-sweep-49</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/1zoffbcw' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/1zoffbcw</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_162004-1zoffbcw\logs</code>
# wandb: Agent Starting Run: 2m5sqrgd with config:
# wandb: 	hidden_channels: 32
# wandb: 	lr: 0.00015338662206795147
# wandb: 	weight_decay: 0.00048570375199378374
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>d:\users\dpa13\projects\my_projects\deeplearning_tutorials\pytorch_geometric\official_examples\wandb\run-20241125_162014-2m5sqrgd</code>
# Syncing run <strong><a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/2m5sqrgd' target="_blank">earthy-sweep-50</a></strong> to <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View project at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a>
#  View sweep at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/sweeps/d99tj2ln</a>
#  View run at <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/2m5sqrgd' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/2m5sqrgd</a>
# 100%|██████████| 100/100 [00:01<00:00, 71.62it/s]
# VBox(children=(Label(value='1.713 MB of 1.738 MB uploaded\r'), FloatProgress(value=0.9855770945756464, max=1.0…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>▁</td></tr><tr><td>gcn/loss</td><td>▇▇▇▆▇▇█▆▇▆▇▇▆▆▆▆▆▅▅▆▄▅▅▅▄▄▄▅▄▃▄▃▃▃▃▂▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gcn/accuracy</td><td>0.611</td></tr><tr><td>gcn/loss</td><td>1.92417</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">earthy-sweep-50</strong> at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/2m5sqrgd' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification/runs/2m5sqrgd</a><br/> View project at: <a href='https://wandb.ai/deepakpokkalla/pyg-node-classification' target="_blank">https://wandb.ai/deepakpokkalla/pyg-node-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20241125_162014-2m5sqrgd\logs</code>
