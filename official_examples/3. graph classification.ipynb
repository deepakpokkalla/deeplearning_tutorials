# %% [markdown]
# ### Graph classification

# %%
import os
import torch
from torch_geometric.datasets import TUDataset

dataset = TUDataset(root='../datasets/TUDataset', name='MUTAG')

print()
print(f'Dataset: {dataset}')
print("===========")
print(f'# graphs: {len(dataset)}')
print(f'# features: {dataset.num_features}')
print(f'# classes: {dataset.num_classes}')
# Out:
# Dataset: MUTAG(188)
# ===========
# # graphs: 188
# # features: 7
# # classes: 2

# %%
data = dataset[0]

print()
print(data)
print('=============')

# gather some info
print(f'# nodes:{data.num_nodes}')
print(f'# edges:{data.num_edges}')
print(f'avg node degree: {data.num_edges/data.num_nodes:.2f}')
print(f'has isolated nodes: {data.has_isolated_nodes()}')
print(f'has self-loops:{data.has_self_loops()}')
print(f'is undirected:{data.is_undirected()}')
# Out:
# Data(edge_index=[2, 38], x=[17, 7], edge_attr=[38, 4], y=[1])
# =============
# # nodes:17
# # edges:38
# avg node degree: 2.24
# has isolated nodes: False
# has self-loops:False
# is undirected:True

# %%
torch.manual_seed(12345)
dataset = dataset.shuffle()

train_dataset = dataset[:150]
test_dataset = dataset[150:]

print(f'# training graphs: {len(train_dataset)}')
print(f'# testing graphs: {len(test_dataset)}')
# Out:
# # training graphs: 150
# # testing graphs: 38

# %% [markdown]
# ### mini-batching of graphs
#
# PyG parallelization across multiple graphs: stack adjacency matrices in a diagonal fashion to create a giant graph that holds multiple isolated subgraphs. Node and target features are simply concatenated in the node dimension.
#
# - PyG batches multiple graphs into a single giant graph
#
# - The "ptr" attribute in the DataBatch object stores the cumulative number of nodes in the graphs at each batch index.
#
# - The "batch" vector/atttribute in the DataBatch object stores the graph number among the total # graphs

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

for step, data in enumerate(train_loader):
    print(f'# graphs in current batch: {data.num_graphs} and step:{step+1}')
    print(data)
    # print(data.ptr)
    # print(type(data.ptr))
    # print(type(data.batch))

    # slice the batchgraph into individual graphs using data.ptr 
    # print(data.batch[:data.ptr[1]])
    # print(data.batch[data.ptr[1]:data.ptr[2]])
# Out:
# # graphs in current batch: 64 and step:1
# DataBatch(edge_index=[2, 2636], x=[1188, 7], edge_attr=[2636, 4], y=[64], batch=[1188], ptr=[65])
# # graphs in current batch: 64 and step:2
# DataBatch(edge_index=[2, 2506], x=[1139, 7], edge_attr=[2506, 4], y=[64], batch=[1139], ptr=[65])
# # graphs in current batch: 22 and step:3
# DataBatch(edge_index=[2, 852], x=[387, 7], edge_attr=[852, 4], y=[22], batch=[387], ptr=[23])

# %% [markdown]
# ### GNN model for graph classification

# %%
dataset.num_features, dataset.num_classes
# Out:
# (7, 2)

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__() # python3: calls parent class w/o explicitly specifying the parent class name [best practice]
        # super(GCN,self).__init__() # python2 & early python3
        torch.manual_seed(12345)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, dataset.num_classes)
    
    def forward(self,x,edge_index,batch):
        # obtain node embeddings
        x = self.conv1(x,edge_index)
        x = x.relu()
        x = self.conv2(x,edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        
        # readout layer 
        x = global_mean_pool(x,batch) # [batch_size, hidden_channels]

        # apply final classifier 
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        # print(x.shape)

        return x #[batch_size, num_classes] ==> [64,2]

model1 = GCN(hidden_channels=64)
print(model1) # shows only the structure defined in the __init__ method.
# Out:
# GCN(
#   (conv1): GCNConv(7, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
len(train_loader), len(train_loader.dataset)
# Out:
# (3, 150)

# %%
model = GCN(hidden_channels=64)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss() # classification problems

def train():
    model.train()

    for data in train_loader:
        out = model(data.x, data.edge_index,data.batch)
        loss = criterion(out, data.y)
        loss.backward() # derive gradients
        optimizer.step() # update parameters based on gradients
        optimizer.zero_grad() # clear gradients

def test(loader):
    model.eval()

    correct = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.batch)
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    return correct/len(loader.dataset)

max_test_acc = 0
for epoch in range(1,171):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    max_test_acc = test_acc if test_acc > max_test_acc else max_test_acc
    print(f'Epoch: {epoch:03d}, train acc: {train_acc:.4f}, test acc: {test_acc:.4f}')
print(max_test_acc)
# Out:
# GCN(
#   (conv1): GCNConv(7, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )
# Epoch: 001, train acc: 0.6467, test acc: 0.7368
# Epoch: 002, train acc: 0.6467, test acc: 0.7368
# Epoch: 003, train acc: 0.6467, test acc: 0.7368
# Epoch: 004, train acc: 0.6467, test acc: 0.7368
# Epoch: 005, train acc: 0.6467, test acc: 0.7368
# Epoch: 006, train acc: 0.6533, test acc: 0.7105
# Epoch: 007, train acc: 0.6467, test acc: 0.7368
# Epoch: 008, train acc: 0.6467, test acc: 0.7368
# Epoch: 009, train acc: 0.6467, test acc: 0.7368
# Epoch: 010, train acc: 0.6467, test acc: 0.7368
# Epoch: 011, train acc: 0.6467, test acc: 0.7368
# Epoch: 012, train acc: 0.6467, test acc: 0.7368
# Epoch: 013, train acc: 0.6400, test acc: 0.7368
# Epoch: 014, train acc: 0.6400, test acc: 0.7105
# Epoch: 015, train acc: 0.6400, test acc: 0.7105
# Epoch: 016, train acc: 0.6267, test acc: 0.7895
# Epoch: 017, train acc: 0.6467, test acc: 0.6842
# Epoch: 018, train acc: 0.6467, test acc: 0.6842
# Epoch: 019, train acc: 0.6467, test acc: 0.7632
# Epoch: 020, train acc: 0.6267, test acc: 0.7895
# Epoch: 021, train acc: 0.6467, test acc: 0.7368
# Epoch: 022, train acc: 0.6467, test acc: 0.7368
# Epoch: 023, train acc: 0.6533, test acc: 0.7105
# Epoch: 024, train acc: 0.6333, test acc: 0.7632
# Epoch: 025, train acc: 0.6467, test acc: 0.7368
# Epoch: 026, train acc: 0.6600, test acc: 0.7368
# Epoch: 027, train acc: 0.6533, test acc: 0.7368
# Epoch: 028, train acc: 0.6533, test acc: 0.7368
# Epoch: 029, train acc: 0.6400, test acc: 0.7105
# Epoch: 030, train acc: 0.6467, test acc: 0.7368
# Epoch: 031, train acc: 0.6667, test acc: 0.7105
# Epoch: 032, train acc: 0.6667, test acc: 0.7895
# Epoch: 033, train acc: 0.6667, test acc: 0.7368
# Epoch: 034, train acc: 0.6400, test acc: 0.6842
# Epoch: 035, train acc: 0.6200, test acc: 0.7895
# Epoch: 036, train acc: 0.6600, test acc: 0.7105
# Epoch: 037, train acc: 0.7267, test acc: 0.7368
# Epoch: 038, train acc: 0.6600, test acc: 0.7105
# Epoch: 039, train acc: 0.6600, test acc: 0.7368
# Epoch: 040, train acc: 0.6600, test acc: 0.7105
# Epoch: 041, train acc: 0.6533, test acc: 0.7368
# Epoch: 042, train acc: 0.6933, test acc: 0.7368
# Epoch: 043, train acc: 0.6733, test acc: 0.6842
# Epoch: 044, train acc: 0.6933, test acc: 0.7632
# Epoch: 045, train acc: 0.6800, test acc: 0.7105
# Epoch: 046, train acc: 0.6600, test acc: 0.7105
# Epoch: 047, train acc: 0.6400, test acc: 0.7632
# Epoch: 048, train acc: 0.6600, test acc: 0.6842
# Epoch: 049, train acc: 0.6867, test acc: 0.7632
# Epoch: 050, train acc: 0.7000, test acc: 0.7368
# Epoch: 051, train acc: 0.6800, test acc: 0.6842
# Epoch: 052, train acc: 0.6667, test acc: 0.7368
# Epoch: 053, train acc: 0.6800, test acc: 0.7105
# Epoch: 054, train acc: 0.7067, test acc: 0.7368
# Epoch: 055, train acc: 0.7000, test acc: 0.7632
# Epoch: 056, train acc: 0.6933, test acc: 0.7368
# Epoch: 057, train acc: 0.6933, test acc: 0.7105
# Epoch: 058, train acc: 0.6800, test acc: 0.7895
# Epoch: 059, train acc: 0.6867, test acc: 0.7632
# Epoch: 060, train acc: 0.7000, test acc: 0.8158
# Epoch: 061, train acc: 0.6467, test acc: 0.7895
# Epoch: 062, train acc: 0.7000, test acc: 0.7368
# Epoch: 063, train acc: 0.6333, test acc: 0.7368
# Epoch: 064, train acc: 0.7000, test acc: 0.6842
# Epoch: 065, train acc: 0.7467, test acc: 0.7895
# Epoch: 066, train acc: 0.6333, test acc: 0.7105
# Epoch: 067, train acc: 0.6400, test acc: 0.7368
# Epoch: 068, train acc: 0.6867, test acc: 0.7632
# Epoch: 069, train acc: 0.6933, test acc: 0.7895
# Epoch: 070, train acc: 0.6733, test acc: 0.7368
# Epoch: 071, train acc: 0.7200, test acc: 0.7105
# Epoch: 072, train acc: 0.7867, test acc: 0.6842
# Epoch: 073, train acc: 0.7267, test acc: 0.6842
# Epoch: 074, train acc: 0.7600, test acc: 0.7895
# Epoch: 075, train acc: 0.7133, test acc: 0.7105
# Epoch: 076, train acc: 0.6600, test acc: 0.7895
# Epoch: 077, train acc: 0.6533, test acc: 0.6579
# Epoch: 078, train acc: 0.7067, test acc: 0.7895
# Epoch: 079, train acc: 0.6333, test acc: 0.7368
# Epoch: 080, train acc: 0.6333, test acc: 0.6842
# Epoch: 081, train acc: 0.6467, test acc: 0.7632
# Epoch: 082, train acc: 0.6667, test acc: 0.7105
# Epoch: 083, train acc: 0.6533, test acc: 0.7368
# Epoch: 084, train acc: 0.6667, test acc: 0.7895
# Epoch: 085, train acc: 0.6333, test acc: 0.6842
# Epoch: 086, train acc: 0.6000, test acc: 0.7368
# Epoch: 087, train acc: 0.7533, test acc: 0.6579
# Epoch: 088, train acc: 0.6667, test acc: 0.7368
# Epoch: 089, train acc: 0.6933, test acc: 0.8158
# Epoch: 090, train acc: 0.7400, test acc: 0.7632
# Epoch: 091, train acc: 0.7200, test acc: 0.6579
# Epoch: 092, train acc: 0.6733, test acc: 0.7368
# Epoch: 093, train acc: 0.7333, test acc: 0.7105
# Epoch: 094, train acc: 0.7133, test acc: 0.7368
# Epoch: 095, train acc: 0.6867, test acc: 0.8158
# Epoch: 096, train acc: 0.6800, test acc: 0.7368
# Epoch: 097, train acc: 0.7000, test acc: 0.7632
# Epoch: 098, train acc: 0.6333, test acc: 0.7368
# Epoch: 099, train acc: 0.6733, test acc: 0.7368
# Epoch: 100, train acc: 0.6800, test acc: 0.6842
# Epoch: 101, train acc: 0.6067, test acc: 0.7105
# Epoch: 102, train acc: 0.6800, test acc: 0.7105
# Epoch: 103, train acc: 0.6467, test acc: 0.6842
# Epoch: 104, train acc: 0.6600, test acc: 0.7632
# Epoch: 105, train acc: 0.6733, test acc: 0.7895
# Epoch: 106, train acc: 0.7000, test acc: 0.6842
# Epoch: 107, train acc: 0.6467, test acc: 0.6316
# Epoch: 108, train acc: 0.7200, test acc: 0.7105
# Epoch: 109, train acc: 0.6600, test acc: 0.7895
# Epoch: 110, train acc: 0.6400, test acc: 0.7368
# Epoch: 111, train acc: 0.7000, test acc: 0.7368
# Epoch: 112, train acc: 0.6333, test acc: 0.7105
# Epoch: 113, train acc: 0.6333, test acc: 0.7368
# Epoch: 114, train acc: 0.6600, test acc: 0.6579
# Epoch: 115, train acc: 0.5200, test acc: 0.7105
# Epoch: 116, train acc: 0.6067, test acc: 0.3421
# Epoch: 117, train acc: 0.6267, test acc: 0.6579
# Epoch: 118, train acc: 0.6267, test acc: 0.7105
# Epoch: 119, train acc: 0.7000, test acc: 0.6842
# Epoch: 120, train acc: 0.6600, test acc: 0.7368
# Epoch: 121, train acc: 0.6800, test acc: 0.7368
# Epoch: 122, train acc: 0.7467, test acc: 0.7105
# Epoch: 123, train acc: 0.6933, test acc: 0.7895
# Epoch: 124, train acc: 0.6600, test acc: 0.7105
# Epoch: 125, train acc: 0.6733, test acc: 0.6316
# Epoch: 126, train acc: 0.6800, test acc: 0.6842
# Epoch: 127, train acc: 0.6867, test acc: 0.6579
# Epoch: 128, train acc: 0.6467, test acc: 0.7105
# Epoch: 129, train acc: 0.6067, test acc: 0.6579
# Epoch: 130, train acc: 0.6067, test acc: 0.5526
# Epoch: 131, train acc: 0.6667, test acc: 0.7895
# Epoch: 132, train acc: 0.6933, test acc: 0.7368
# Epoch: 133, train acc: 0.6600, test acc: 0.7368
# Epoch: 134, train acc: 0.7133, test acc: 0.7632
# Epoch: 135, train acc: 0.7000, test acc: 0.6842
# Epoch: 136, train acc: 0.7333, test acc: 0.6842
# Epoch: 137, train acc: 0.7333, test acc: 0.6842
# Epoch: 138, train acc: 0.6933, test acc: 0.7368
# Epoch: 139, train acc: 0.6800, test acc: 0.7632
# Epoch: 140, train acc: 0.6733, test acc: 0.7368
# Epoch: 141, train acc: 0.6733, test acc: 0.6053
# Epoch: 142, train acc: 0.6733, test acc: 0.6579
# Epoch: 143, train acc: 0.7067, test acc: 0.6842
# Epoch: 144, train acc: 0.7200, test acc: 0.6316
# Epoch: 145, train acc: 0.6667, test acc: 0.7368
# Epoch: 146, train acc: 0.6933, test acc: 0.6842
# Epoch: 147, train acc: 0.7200, test acc: 0.7368
# Epoch: 148, train acc: 0.7267, test acc: 0.7105
# Epoch: 149, train acc: 0.7200, test acc: 0.7368
# Epoch: 150, train acc: 0.7333, test acc: 0.7632
# Epoch: 151, train acc: 0.6533, test acc: 0.7105
# Epoch: 152, train acc: 0.6733, test acc: 0.7368
# Epoch: 153, train acc: 0.6600, test acc: 0.7368
# Epoch: 154, train acc: 0.6533, test acc: 0.7368
# Epoch: 155, train acc: 0.6667, test acc: 0.7632
# Epoch: 156, train acc: 0.7067, test acc: 0.7895
# Epoch: 157, train acc: 0.7400, test acc: 0.7105
# Epoch: 158, train acc: 0.6933, test acc: 0.7105
# Epoch: 159, train acc: 0.6267, test acc: 0.7368
# Epoch: 160, train acc: 0.7067, test acc: 0.7895
# Epoch: 161, train acc: 0.6400, test acc: 0.7895
# Epoch: 162, train acc: 0.6400, test acc: 0.6053
# Epoch: 163, train acc: 0.6800, test acc: 0.7105
# Epoch: 164, train acc: 0.5933, test acc: 0.7368
# Epoch: 165, train acc: 0.7200, test acc: 0.6579
# Epoch: 166, train acc: 0.6600, test acc: 0.6842
# Epoch: 167, train acc: 0.6733, test acc: 0.7105
# Epoch: 168, train acc: 0.6400, test acc: 0.6842
# Epoch: 169, train acc: 0.6067, test acc: 0.8158
# Epoch: 170, train acc: 0.6533, test acc: 0.6579
# 0.8157894736842105

# %% [markdown]
# - neighborhood normalization decreases the expressivity of GNNs in distinguishing certain graph structures
# - use GraphConv instead of GCNConv
#
# - Note: Using GraphConv instead of GCNConv improved test accuracy from 81% to 84%

# %%
from torch_geometric.nn import GraphConv

class GNN(torch.nn.Module):
    def __init__(self,hidden_channels):
        super(GNN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GraphConv(dataset.num_features,hidden_channels)
        self.conv2 = GraphConv(hidden_channels,hidden_channels)
        self.conv3 = GraphConv(hidden_channels,hidden_channels)
        self.lin = Linear(hidden_channels,dataset.num_classes)
    
    def forward(self,x,edge_index,batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        x = global_mean_pool(x, batch)

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
    
        return x

model2 = GNN(hidden_channels=64)
print(model2)
# Out:
# GNN(
#   (conv1): GraphConv(7, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GraphConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
model = GNN(hidden_channels=64)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

max_test_acc = 0 
for epoch in range(1,201):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    max_test_acc = test_acc if test_acc > max_test_acc else max_test_acc
    print(f'Epoch: {epoch:03d}, train_acc: {train_acc:.4f}, test_acc: {test_acc:.4f}')
print(max_test_acc)
# Out:
# GNN(
#   (conv1): GraphConv(7, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GraphConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )
# Epoch: 001, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 002, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 003, train_acc: 0.5000, test_acc: 0.3158
# Epoch: 004, train_acc: 0.6533, test_acc: 0.7368
# Epoch: 005, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 006, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 007, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 008, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 009, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 010, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 011, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 012, train_acc: 0.6600, test_acc: 0.7895
# Epoch: 013, train_acc: 0.6400, test_acc: 0.8158
# Epoch: 014, train_acc: 0.6933, test_acc: 0.7368
# Epoch: 015, train_acc: 0.6800, test_acc: 0.7368
# Epoch: 016, train_acc: 0.6733, test_acc: 0.7105
# Epoch: 017, train_acc: 0.6733, test_acc: 0.7895
# Epoch: 018, train_acc: 0.6667, test_acc: 0.7895
# Epoch: 019, train_acc: 0.6867, test_acc: 0.7368
# Epoch: 020, train_acc: 0.7267, test_acc: 0.7105
# Epoch: 021, train_acc: 0.6800, test_acc: 0.7368
# Epoch: 022, train_acc: 0.6800, test_acc: 0.7105
# Epoch: 023, train_acc: 0.7467, test_acc: 0.7368
# Epoch: 024, train_acc: 0.6600, test_acc: 0.8158
# Epoch: 025, train_acc: 0.6533, test_acc: 0.7368
# Epoch: 026, train_acc: 0.6533, test_acc: 0.7368
# Epoch: 027, train_acc: 0.6533, test_acc: 0.7368
# Epoch: 028, train_acc: 0.6267, test_acc: 0.7368
# Epoch: 029, train_acc: 0.6267, test_acc: 0.7632
# Epoch: 030, train_acc: 0.6267, test_acc: 0.7105
# Epoch: 031, train_acc: 0.6400, test_acc: 0.8421
# Epoch: 032, train_acc: 0.6733, test_acc: 0.7105
# Epoch: 033, train_acc: 0.6600, test_acc: 0.7368
# Epoch: 034, train_acc: 0.6467, test_acc: 0.7632
# Epoch: 035, train_acc: 0.6867, test_acc: 0.7632
# Epoch: 036, train_acc: 0.7333, test_acc: 0.7632
# Epoch: 037, train_acc: 0.7267, test_acc: 0.7368
# Epoch: 038, train_acc: 0.7467, test_acc: 0.7895
# Epoch: 039, train_acc: 0.6533, test_acc: 0.7632
# Epoch: 040, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 041, train_acc: 0.6467, test_acc: 0.7632
# Epoch: 042, train_acc: 0.7133, test_acc: 0.7368
# Epoch: 043, train_acc: 0.7067, test_acc: 0.6579
# Epoch: 044, train_acc: 0.7000, test_acc: 0.7105
# Epoch: 045, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 046, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 047, train_acc: 0.5600, test_acc: 0.7105
# Epoch: 048, train_acc: 0.6400, test_acc: 0.6842
# Epoch: 049, train_acc: 0.6267, test_acc: 0.7368
# Epoch: 050, train_acc: 0.6267, test_acc: 0.7632
# Epoch: 051, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 052, train_acc: 0.6800, test_acc: 0.7368
# Epoch: 053, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 054, train_acc: 0.6400, test_acc: 0.6842
# Epoch: 055, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 056, train_acc: 0.6200, test_acc: 0.7105
# Epoch: 057, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 058, train_acc: 0.6600, test_acc: 0.6579
# Epoch: 059, train_acc: 0.6333, test_acc: 0.6579
# Epoch: 060, train_acc: 0.6533, test_acc: 0.7895
# Epoch: 061, train_acc: 0.6867, test_acc: 0.6842
# Epoch: 062, train_acc: 0.3267, test_acc: 0.6053
# Epoch: 063, train_acc: 0.4400, test_acc: 0.6316
# Epoch: 064, train_acc: 0.6000, test_acc: 0.2368
# Epoch: 065, train_acc: 0.6067, test_acc: 0.6579
# Epoch: 066, train_acc: 0.6267, test_acc: 0.7105
# Epoch: 067, train_acc: 0.6267, test_acc: 0.6842
# Epoch: 068, train_acc: 0.6467, test_acc: 0.8158
# Epoch: 069, train_acc: 0.6267, test_acc: 0.6842
# Epoch: 070, train_acc: 0.6400, test_acc: 0.7632
# Epoch: 071, train_acc: 0.6533, test_acc: 0.7632
# Epoch: 072, train_acc: 0.6667, test_acc: 0.7368
# Epoch: 073, train_acc: 0.6267, test_acc: 0.7895
# Epoch: 074, train_acc: 0.6667, test_acc: 0.7632
# Epoch: 075, train_acc: 0.7467, test_acc: 0.8421
# Epoch: 076, train_acc: 0.6533, test_acc: 0.7895
# Epoch: 077, train_acc: 0.7200, test_acc: 0.7632
# Epoch: 078, train_acc: 0.6533, test_acc: 0.6842
# Epoch: 079, train_acc: 0.6333, test_acc: 0.7632
# Epoch: 080, train_acc: 0.5667, test_acc: 0.7632
# Epoch: 081, train_acc: 0.7467, test_acc: 0.8421
# Epoch: 082, train_acc: 0.7133, test_acc: 0.7632
# Epoch: 083, train_acc: 0.7000, test_acc: 0.6579
# Epoch: 084, train_acc: 0.7000, test_acc: 0.6053
# Epoch: 085, train_acc: 0.6467, test_acc: 0.6579
# Epoch: 086, train_acc: 0.6200, test_acc: 0.6842
# Epoch: 087, train_acc: 0.6867, test_acc: 0.7895
# Epoch: 088, train_acc: 0.6333, test_acc: 0.7632
# Epoch: 089, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 090, train_acc: 0.4200, test_acc: 0.2368
# Epoch: 091, train_acc: 0.3800, test_acc: 0.2895
# Epoch: 092, train_acc: 0.4467, test_acc: 0.6316
# Epoch: 093, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 094, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 095, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 096, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 097, train_acc: 0.6400, test_acc: 0.6842
# Epoch: 098, train_acc: 0.6067, test_acc: 0.6842
# Epoch: 099, train_acc: 0.6267, test_acc: 0.7368
# Epoch: 100, train_acc: 0.6067, test_acc: 0.6579
# Epoch: 101, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 102, train_acc: 0.6800, test_acc: 0.7368
# Epoch: 103, train_acc: 0.6933, test_acc: 0.6842
# Epoch: 104, train_acc: 0.6600, test_acc: 0.7105
# Epoch: 105, train_acc: 0.6333, test_acc: 0.6842
# Epoch: 106, train_acc: 0.7133, test_acc: 0.6842
# Epoch: 107, train_acc: 0.7000, test_acc: 0.6842
# Epoch: 108, train_acc: 0.6600, test_acc: 0.6842
# Epoch: 109, train_acc: 0.5933, test_acc: 0.7895
# Epoch: 110, train_acc: 0.6667, test_acc: 0.7368
# Epoch: 111, train_acc: 0.6800, test_acc: 0.6579
# Epoch: 112, train_acc: 0.6667, test_acc: 0.6842
# Epoch: 113, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 114, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 115, train_acc: 0.6467, test_acc: 0.6842
# Epoch: 116, train_acc: 0.6267, test_acc: 0.7105
# Epoch: 117, train_acc: 0.6733, test_acc: 0.6842
# Epoch: 118, train_acc: 0.6600, test_acc: 0.7368
# Epoch: 119, train_acc: 0.6667, test_acc: 0.6053
# Epoch: 120, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 121, train_acc: 0.6333, test_acc: 0.7895
# Epoch: 122, train_acc: 0.6600, test_acc: 0.6579
# Epoch: 123, train_acc: 0.7000, test_acc: 0.7368
# Epoch: 124, train_acc: 0.6200, test_acc: 0.6842
# Epoch: 125, train_acc: 0.6533, test_acc: 0.6842
# Epoch: 126, train_acc: 0.6333, test_acc: 0.6579
# Epoch: 127, train_acc: 0.6133, test_acc: 0.7368
# Epoch: 128, train_acc: 0.6267, test_acc: 0.6842
# Epoch: 129, train_acc: 0.6267, test_acc: 0.7105
# Epoch: 130, train_acc: 0.6333, test_acc: 0.6316
# Epoch: 131, train_acc: 0.6333, test_acc: 0.6579
# Epoch: 132, train_acc: 0.6400, test_acc: 0.7105
# Epoch: 133, train_acc: 0.6400, test_acc: 0.6579
# Epoch: 134, train_acc: 0.6333, test_acc: 0.6842
# Epoch: 135, train_acc: 0.6400, test_acc: 0.7368
# Epoch: 136, train_acc: 0.6467, test_acc: 0.7632
# Epoch: 137, train_acc: 0.6400, test_acc: 0.7368
# Epoch: 138, train_acc: 0.6267, test_acc: 0.7105
# Epoch: 139, train_acc: 0.6267, test_acc: 0.6579
# Epoch: 140, train_acc: 0.6267, test_acc: 0.7632
# Epoch: 141, train_acc: 0.6267, test_acc: 0.7368
# Epoch: 142, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 143, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 144, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 145, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 146, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 147, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 148, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 149, train_acc: 0.6400, test_acc: 0.7368
# Epoch: 150, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 151, train_acc: 0.6333, test_acc: 0.7632
# Epoch: 152, train_acc: 0.6467, test_acc: 0.7368
# Epoch: 153, train_acc: 0.6133, test_acc: 0.7632
# Epoch: 154, train_acc: 0.6200, test_acc: 0.7895
# Epoch: 155, train_acc: 0.6467, test_acc: 0.6842
# Epoch: 156, train_acc: 0.7133, test_acc: 0.6842
# Epoch: 157, train_acc: 0.6200, test_acc: 0.7368
# Epoch: 158, train_acc: 0.6467, test_acc: 0.6842
# Epoch: 159, train_acc: 0.7000, test_acc: 0.6579
# Epoch: 160, train_acc: 0.6067, test_acc: 0.7368
# Epoch: 161, train_acc: 0.6333, test_acc: 0.6579
# Epoch: 162, train_acc: 0.6133, test_acc: 0.6316
# Epoch: 163, train_acc: 0.6667, test_acc: 0.7105
# Epoch: 164, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 165, train_acc: 0.6333, test_acc: 0.7368
# Epoch: 166, train_acc: 0.5933, test_acc: 0.7105
# Epoch: 167, train_acc: 0.6600, test_acc: 0.7368
# Epoch: 168, train_acc: 0.6200, test_acc: 0.7368
# Epoch: 169, train_acc: 0.6133, test_acc: 0.6842
# Epoch: 170, train_acc: 0.6267, test_acc: 0.6316
# Epoch: 171, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 172, train_acc: 0.6533, test_acc: 0.7105
# Epoch: 173, train_acc: 0.6467, test_acc: 0.7632
# Epoch: 174, train_acc: 0.6333, test_acc: 0.7895
# Epoch: 175, train_acc: 0.6400, test_acc: 0.7368
# Epoch: 176, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 177, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 178, train_acc: 0.7267, test_acc: 0.6579
# Epoch: 179, train_acc: 0.6533, test_acc: 0.7895
# Epoch: 180, train_acc: 0.6667, test_acc: 0.6579
# Epoch: 181, train_acc: 0.4067, test_acc: 0.3684
# Epoch: 182, train_acc: 0.6267, test_acc: 0.6842
# Epoch: 183, train_acc: 0.5867, test_acc: 0.6579
# Epoch: 184, train_acc: 0.6733, test_acc: 0.6842
# Epoch: 185, train_acc: 0.6333, test_acc: 0.7105
# Epoch: 186, train_acc: 0.6667, test_acc: 0.7105
# Epoch: 187, train_acc: 0.6200, test_acc: 0.6842
# Epoch: 188, train_acc: 0.6133, test_acc: 0.7632
# Epoch: 189, train_acc: 0.6467, test_acc: 0.6579
# Epoch: 190, train_acc: 0.6400, test_acc: 0.6842
# Epoch: 191, train_acc: 0.5933, test_acc: 0.6579
# Epoch: 192, train_acc: 0.6333, test_acc: 0.6579
# Epoch: 193, train_acc: 0.6200, test_acc: 0.6842
# Epoch: 194, train_acc: 0.6467, test_acc: 0.7632
# Epoch: 195, train_acc: 0.6400, test_acc: 0.7368
# Epoch: 196, train_acc: 0.6267, test_acc: 0.7368
# Epoch: 197, train_acc: 0.6467, test_acc: 0.7105
# Epoch: 198, train_acc: 0.6067, test_acc: 0.7368
# Epoch: 199, train_acc: 0.6067, test_acc: 0.7105
# Epoch: 200, train_acc: 0.6667, test_acc: 0.6842
# 0.8421052631578947

# %% [markdown]
# ### comparing global max and mean pool operations

# %%
from torch_geometric.nn import global_max_pool, global_mean_pool
import torch

# %%
a = torch.randint(1,10,size=(4,3))
# batch = torch.tensor([0,0,1,1])
batch =  torch.zeros(4).long()
print(a,batch)

# %%
global_max_pool(a,batch), global_mean_pool(a,batch)
